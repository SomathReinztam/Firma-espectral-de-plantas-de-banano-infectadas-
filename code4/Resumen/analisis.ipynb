# %%
import os
import pandas as pd
import data_funtions as datf

# %%
path = r"C:\Users\Acer\Documents\python\Proyecto de investigacion\sets"
path = path.replace('\\', '/')

# %%
file = 'datos.csv'
file = os.path.join(path, file)

df = pd.read_csv(file, sep=';')
df
# Out:
#      dpi  Sana  Tratamiento  Planta  400.385  400.843  401.302  401.761
# 0      0     1            0       1     0.00     0.00     0.00      0.0  \
# 1      0     1            0       2     0.00     0.00     0.00      0.0
# 2      0     1            0       3     0.00     0.00     0.00      0.0
# 3      0     1            0       4     0.00     0.00     0.00      0.0
# 4      0     1            0       5     0.00     0.00     0.00      0.0
# ..   ...   ...          ...     ...      ...      ...      ...      ...
# 662   21     0            5      25     0.00     0.00     0.00      0.0
# 663   21     0            5      27     0.00     0.00     0.00      0.0
# 664   21     0            5      28     1.04     1.13     1.87      1.1
# 665   21     0            5      29     0.00     0.00     0.00      0.0
# 666   21     0            5      30     0.00     0.00     0.00      0.0
#
#      402.219  402.678  ...  996.43  996.852  997.274  997.696  998.118
# ...

# %%
datf.resumen_datos(df)
# Out:
# Número de filas y columnas: (667, 1368)
#
# Tipos de variables:
# dpi              int64
# Sana             int64
# Tratamiento      int64
# Planta           int64
# 400.385        float64
#                 ...
# 998.54         float64
# 998.962        float64
# 999.384        float64
# 999.806        float64
# 1000.228       float64
# Length: 1368, dtype: object
#
# Conteo de valores nulos por columna:
# dpi            0
# Sana           0
# Tratamiento    0
# Planta         0
# 400.385        0
#               ..
# 998.54         0
# 998.962        0
# 999.384        0
# 999.806        0
# 1000.228       0
# Length: 1368, dtype: int64
#
# Número total de valores nulos: 0
#
# Porcentaje de valores nulos por columna:
# dpi            0.0
# Sana           0.0
# Tratamiento    0.0
# Planta         0.0
# 400.385        0.0
#               ...
# 998.54         0.0
# 998.962        0.0
# 999.384        0.0
# 999.806        0.0
# 1000.228       0.0
# Length: 1368, dtype: float64
#
# ...

# %%
datf.plot_describe(df.describe())

# %%
filtro = (df['Sana'] == 1)
df_filtro = df[filtro]
datf.plot_describe(df_filtro.describe())

# %%
filtro = (df['Tratamiento'] == 3) & (df['dpi'] == 21)
df_filtro = df[filtro]
datf.plot_describe(df_filtro.describe())

# %%
df_filtro = df.iloc[:, 4:]
datf.plot_heat_map(df_filtro)

# %%
Tratamiento = 5
Planta = 21
datf.ver_planta(df,Tratamiento, Planta)

# %%
Tratamiento = 0
Planta = 3
datf.ver_planta(df,Tratamiento, Planta)

# %%
Tratamiento = 0
Planta = 25
datf.ver_planta(df,Tratamiento, Planta)

# %%
Tratamiento = 1
Planta = 17
datf.ver_planta(df,Tratamiento, Planta)

# %%
Tratamiento = 1
Planta = 10
datf.ver_planta(df,Tratamiento, Planta)

# %%
a = ((df['dpi'] == 7) & (df['Planta'] == 17) & (df['Tratamiento'] == 3))
b = ((df['dpi'] == 21) & (df['Planta'] == 9) & (df['Tratamiento'] == 5))
filtro = a | b
datf.ver_plantas_filtro(df, filtro)

# %%
filtro = (df['dpi'] == 7) & (df['Tratamiento'] == 3)
datf.ver_mean_std(df, filtro)

# %%
filtro = (df['Sana'] == 1)
datf.ver_mean_std(df, filtro)

# %%
filtro = (df['Sana'] == 0)
datf.ver_mean_std(df, filtro)

# %%
filtros = [
    (df['dpi'] == 0) & (df['Tratamiento'] != 0),
    (df['Tratamiento'] == 0)
]
datf.ver_Means_Stds_free(df, filtros)

# %%
file = 'datos_PCA_2d.csv'
file = os.path.join(path, file)

df = pd.read_csv(file, sep=';')
df
# Out:
#      dpi  Sana  Tratamiento  Planta       eje_x       eje_y
# 0      0     1            0       1  -88.313525  -69.610306
# 1      0     1            0       2  133.979912 -186.410223
# 2      0     1            0       3  -53.907047 -163.198706
# 3      0     1            0       4  -29.544776   52.261756
# 4      0     1            0       5 -208.177720   47.243916
# ..   ...   ...          ...     ...         ...         ...
# 662   21     0            5      25   99.706059  -66.346871
# 663   21     0            5      27 -101.267724  -83.111645
# 664   21     0            5      28  276.740505  135.257083
# 665   21     0            5      29  -84.256712  -24.713064
# 666   21     0            5      30  133.734976  -82.692072
#
# [667 rows x 6 columns]

# %%
datf.plot_datos_PCA_2d(df)

# %%
df_filtro = None

# %%
import plot_model as pml
import pickle

# %%
path = r"C:\Users\Acer\Documents\python\Proyecto de investigacion\code4\Sets"
path = path.replace("\\", "/")

# %%
file = 'model_SVMc_linear.pkl'
file = os.path.join(path, file)


with open(file, 'rb') as f:
    clf = pickle.load(f)

X_data, y_data = pml.get_datos(random_state=96, etiqueta='Sana')


pml.plot_clf_model(clf, X_data, y_data)
# Out:
# score: 0.9651741293532339

# %%
import learning_Curve as lc
from sklearn.svm import SVC

# %%
hparams = {'C': 0.3020408163265306, 'kernel':'linear'}
clf = SVC(**hparams)
scoring = 'accuracy'
lc.plot_clf_learning_Curve(clf, df,scoring)

# %%
file = 'model_Ridge_linear_reg.pkl'
file = os.path.join(path, file)

with open(file, 'rb') as f:
    reg = pickle.load(f)

X_data, y_data = pml.get_datos(random_state=203, etiqueta='dpi')

pml.plot_reg_model(reg, X_data, y_data)
# Out:
# data mean_absolute_error: 0.9043895875216106

# %%
from sklearn.linear_model import Ridge

# %%
reg = Ridge(7)
scoring='neg_mean_absolute_error'
lc.plot_reg_learning_Curve(reg, df, scoring)
